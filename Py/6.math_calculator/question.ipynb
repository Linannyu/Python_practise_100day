# %% [markdown]
# # 2026 AP Calc BC Summer Prep
# ---
# # Summer Assignment #1: Pre-Calculus Review

# %%
from math_calculator import *

# %% [markdown]
# # Quadratic Trig Equations (Level 1)
#
# Find all angles, 0° ≤ θ < 360°, that satisfy the equation below, to the nearest tenth of a degree.
#
# $csc^2(θ) - 3csc(θ) - 4 = 0$
#
# Solve:
#
# $csc(θ) = -1,csc(θ) = 4$
#
# $csc(θ) = \frac{1}{sin(θ)}$
#
# $sin(θ) = \frac{1}{4}$ and $sin(θ) = -1$
#
# $θ =sin^{-1}(\frac{1}{4}) = 14.5°$.Because sin(θ) is positive, θ is in the I and II quadrant, so the solution is 14.5° and 165.5°.
#
# $θ = sin^{-1}(-1) = 270°$
#
# $θ = 14.5°, 165.5°, 270°$

# %%
# Step 1: Solve the equation
value = calu('solve', 'x**2 - 3*x - 4 = 0')
# Step 2: convert
for i in value:
    va = reciprocal_convert('csc',i)
    fun = va[0]
    value = va[1]
# Out:
# [-1, 4]
# -1
# (sin, -1)
# 4
# (sin, 1/4)
